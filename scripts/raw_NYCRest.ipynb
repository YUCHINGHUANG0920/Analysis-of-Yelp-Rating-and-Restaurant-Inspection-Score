# %%
import pandas as pd
import math

# %% [markdown]
# ### Extract Data

# %%
URL = 'https://data.cityofnewyork.us/resource/43nn-pn8j.json'
offset = 0
limit = 1000

df_raw = pd.DataFrame()

# %%
while True:
    url = URL + f'?$limit={limit}&$offset={offset}'
    df_chunk = pd.read_json(url)
    df_raw = pd.concat([df_raw, df_chunk], ignore_index=True)

    if len(df_chunk) < limit:
        break

    offset += limit

# %% [markdown]
# ### Check Dataset

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224367 entries, 0 to 224366
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  224367 non-null  int64
#  1   dba                    223811 non-null  object
#  2   boro                   224367 non-null  object
#  3   building               223971 non-null  object
#  4   street                 224367 non-null  object
#  5   zipcode                221594 non-null  object
#  6   phone                  224364 non-null  object
#  7   inspection_date        224367 non-null  object
#  8   critical_flag          224367 non-null  object
#  9   record_date            224367 non-null  object
#  10  latitude               224085 non-null  float64
#  11  longitude              224085 non-null  float64
#  12  community_board        220959 non-null  float64
#  13  council_district       220963 non-null  float64
#  14  census_tract           220963 non-null  float64
#  15  bin                    219819 non-null  float64
#  16  bbl                    223732 non-null  float64
#  17  nta                    220959 non-null  object
#  18  cuisine_description    222074 non-null  object
#  19  action                 222074 non-null  object
#  20  score                  213626 non-null  float64
#  21  grade                  110502 non-null  object
#  22  grade_date             102092 non-null  object
#  23  inspection_type        222074 non-null  object
#  24  violation_code         220924 non-null  object
#  25  violation_description  220924 non-null  object
# dtypes: float64(8), int64(1), object(17)
# memory usage: 44.5+ MB

# %% [markdown]
# (No *location point1* in extract data)

# %%
df_raw.head()
# Out:
#       camis                        dba           boro building  \
# 0  50122211  STATEN ISLAND FERRY HAWKS  Staten Island       75
# 1  50135220                      SHISO      Manhattan      214
# 2  50148541               TIPICO56 LLC      Manhattan      177
# 3  50149643        TIA ELI'S REATURANT       Brooklyn        5
# 4  50106703                     J-SPEC      Manhattan      239
#
#              street zipcode         phone          inspection_date  \
# 0  RICHMOND TERRACE   10301  9172843261.0  1900-01-01T00:00:00.000
# 1  EAST    9 STREET   10003  8563046681.0  1900-01-01T00:00:00.000
# 2    SHERMAN AVENUE   10034  9295034336.0  1900-01-01T00:00:00.000
# 3  EAST   31 STREET   11226  3479579837.0  1900-01-01T00:00:00.000
# 4  EAST    5 STREET   10003  3472903669.0  1900-01-01T00:00:00.000
#
#     critical_flag              record_date  ...           bbl   nta  \
# 0  Not Applicable  2024-04-14T06:00:11.000  ...  5.000020e+09  SI22
# 1  Not Applicable  2024-04-14T06:00:11.000  ...  1.004648e+09  MN22
# 2  Not Applicable  2024-04-14T06:00:11.000  ...  1.022210e+09  MN01
# 3  Not Applicable  2024-04-14T06:00:11.000  ...  3.048850e+09  BK95
# 4  Not Applicable  2024-04-14T06:00:11.000  ...  1.004610e+09  MN22
#
#    cuisine_description  action  score  grade  grade_date inspection_type  \
# 0                  NaN     NaN    NaN    NaN         NaN             NaN
# 1                  NaN     NaN    NaN    NaN         NaN             NaN
# 2                  NaN     NaN    NaN    NaN         NaN             NaN
# 3                  NaN     NaN    NaN    NaN         NaN             NaN
# 4                  NaN     NaN    NaN    NaN         NaN             NaN
#
#   violation_code violation_description
# 0            NaN                   NaN
# 1            NaN                   NaN
# 2            NaN                   NaN
# 3            NaN                   NaN
# 4            NaN                   NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Remove columns with entirely missing data

# %%
df_raw.dropna(how='all', inplace=True)
df_raw.shape
# Out:
# (224367, 26)

# %% [markdown]
# Remove columns outside our Dimensions/Facts Table

# %%
df_cleaned = df_raw.copy().drop(columns = ['bin','bbl','nta','census_tract','council_district','community_board'])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224367 entries, 0 to 224366
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  224367 non-null  int64
#  1   dba                    223811 non-null  object
#  2   boro                   224367 non-null  object
#  3   building               223971 non-null  object
#  4   street                 224367 non-null  object
#  5   zipcode                221594 non-null  object
#  6   phone                  224364 non-null  object
#  7   inspection_date        224367 non-null  object
#  8   critical_flag          224367 non-null  object
#  9   record_date            224367 non-null  object
#  10  latitude               224085 non-null  float64
#  11  longitude              224085 non-null  float64
#  12  cuisine_description    222074 non-null  object
#  13  action                 222074 non-null  object
#  14  score                  213626 non-null  float64
#  15  grade                  110502 non-null  object
#  16  grade_date             102092 non-null  object
#  17  inspection_type        222074 non-null  object
#  18  violation_code         220924 non-null  object
#  19  violation_description  220924 non-null  object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 34.2+ MB

# %% [markdown]
# Remove columns with less than 60% data

# %%
df_cleaned.dropna(axis=0, thresh=int(df_cleaned.shape[1]*0.6)+1, inplace = True)
df_cleaned.shape
# Out:
# (222073, 20)

# %%
df_cleaned.head()
# Out:
#        camis                      dba       boro building            street  \
# 15  41395521  CITI FIELD FOXWOODS BAR     Queens      126  ROOSEVELT AVENUE
# 27  50083465             MALA PROJECT  Manhattan      122          1 AVENUE
# 30  41543970               PAUSE CAFE  Manhattan        3     CLINTON SREET
# 35  50070366            VILLAGE DINER     Queens     8174     LEFFERTS BLVD
# 36  41280221                 WOORIJIP  Manhattan       12  WEST   32 STREET
#
#    zipcode         phone          inspection_date   critical_flag  \
# 15     NaN  7185958100.0  2017-06-13T00:00:00.000  Not Applicable
# 27   10009  2126021005.0  2022-04-19T00:00:00.000        Critical
# 30     NaN  2126775415.0  2022-09-27T00:00:00.000        Critical
# 35   11415  7188503787.0  2023-02-09T00:00:00.000    Not Critical
# 36   10001  2122441115.0  2022-05-18T00:00:00.000    Not Critical
#
#                 record_date   latitude  longitude cuisine_description  \
# 15  2024-04-14T06:00:09.000   0.000000   0.000000            American
# 27  2024-04-14T06:00:09.000  40.727181 -73.985572             Chinese
# 30  2024-04-14T06:00:09.000   0.000000   0.000000      Middle Eastern
# 35  2024-04-14T06:00:09.000  40.707959 -73.830981            American
# 36  2024-04-14T06:00:09.000  40.747468 -73.986278              Korean
#
#                                                action  score grade  \
# 15  No violations were recorded at the time of thi...    0.0     A
# 27    Violations were cited in the following area(s).   33.0   NaN
# 30    Violations were cited in the following area(s).   12.0     A
# 35    Violations were cited in the following area(s).   25.0   NaN
# 36    Violations were cited in the following area(s).    NaN   NaN
#
#                  grade_date  \
# 15  2017-06-13T00:00:00.000
# 27                      NaN
# 30  2022-09-27T00:00:00.000
# 35                      NaN
# 36                      NaN
#
#                                       inspection_type violation_code  \
# 15              Cycle Inspection / Initial Inspection            NaN
# 27              Cycle Inspection / Initial Inspection            02B
# 30                   Cycle Inspection / Re-inspection            02B
# 35              Cycle Inspection / Initial Inspection            09B
# 36  Administrative Miscellaneous / Initial Inspection            22F
#
#                              violation_description
# 15                                             NaN
# 27      Hot food item not held at or above 140º F.
# 30  Hot TCS food item not held at or above 140 °F.
# 35                     Thawing procedure improper.
# 36                         MISBRANDED AND LABELING
