# %%
# !pip install fuzzywuzzy python-Levenshtein
# !pip install azure-storage-blob
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein)
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 4.4 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein)
#   Downloading rapidfuzz-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.3 MB/s eta 0:00:00
# Installing collected packages: fuzzywuzzy, rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.25.1 fuzzywuzzy-0.18.0 python-Levenshtein-0.25.1 rapidfuzz-3.8.1
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.19.1-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 5.0 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-storage-blob)
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.30.1 azure-storage-blob-12.19.1 isodate-0.6.1

# %%
import pandas as pd
import numpy as np
import requests
import json
from sklearn.cluster import DBSCAN
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import math
from azure.storage.blob import BlobServiceClient
import io
from io import StringIO

# %%
#specify the path to your JSON file
token_file_path = 'token.json'

#Load the JSON token file
with open(token_file_path,'r') as token_file:
    token=json.load(token_file)

# %% [markdown]
# Define Functions

# %%
def scoringTable(nametoevaluate, company_list, fuzzObject):

    scorer_list = ['ratio','partial_ratio','token_set_ratio','partial_token_set_ratio','token_sort_ratio','partial_token_sort_ratio','QRatio','UQRatio','WRatio','UWRatio']
    dataFrame = pd.DataFrame()
    for scorer in scorer_list:
        scorer_function = getattr(fuzz, scorer)
        scorer_result = process.extract(nametoevaluate, company_list, scorer=scorer_function)
        scorer_result_list = [result + (scorer,) for result in scorer_result]
        dataFrame = dataFrame.append(pd.DataFrame(scorer_result_list,columns=['Name', 'Score', 'Scorer']))

    df_sorted = dataFrame.sort_values('Score', ascending=False)
    df_sorted.reset_index(drop=True,inplace=True)
    df_grouped = df_sorted.groupby('Name').agg(Score_Sum=('Score', 'sum'), Score_Count=('Name', 'count'))
    df_grouped['Average'] = df_grouped['Score_Sum'] / df_grouped['Score_Count']
    df_grouped = df_grouped.sort_values('Average', ascending=False)
    return df_grouped.iloc[0, 0]


# Mock function simulating the API call, returning multiple restaurants
# 1st token
def query_api(Latitude, Longitude):
  TOKEN = token["token1"]
  headers = { "accept": "application/json", "Authorization": f"Bearer {TOKEN}"}
  url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={Latitude}&longitude={Longitude}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
  response = requests.get(url, headers=headers)
  if response.status_code == 200:
    data = response.json()
    business_names = [business['name'] for business in data['businesses']]
  return data['businesses'], business_names

# %% [markdown]
# Downloaded the source file for extracting Yelp dataset

# %%
config_file_path = 'config.json'

# Load the JSON configuration file
with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

connection_string = config["connectionString"]

blob_service_client = BlobServiceClient.from_connection_string(connection_string)

container_name = "groupproject"
blob_name = "groupdata2_raw_NYCRest.csv"

blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
data = blob_client.download_blob()
csv_data = data.content_as_text()  # Get CSV data as text

# Process CSV data (example: load into pandas DataFrame)
restaurant_data = pd.read_csv(io.StringIO(csv_data))

# %%
restaurant_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221979 entries, 0 to 221978
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  221979 non-null  int64
#  1   dba                    221979 non-null  object
#  2   boro                   221979 non-null  object
#  3   building               221593 non-null  object
#  4   street                 221979 non-null  object
#  5   zipcode                219240 non-null  float64
#  6   phone                  221979 non-null  object
#  7   inspection_date        221979 non-null  object
#  8   critical_flag          221979 non-null  object
#  9   record_date            221979 non-null  object
#  10  latitude               221723 non-null  float64
#  11  longitude              221723 non-null  float64
#  12  cuisine_description    221979 non-null  object
#  13  action                 221979 non-null  object
#  14  score                  213531 non-null  float64
#  15  inspection_type        221979 non-null  object
#  16  violation_code         220830 non-null  object
#  17  violation_description  220830 non-null  object
#  18  grade                  110443 non-null  object
#  19  grade_date             102033 non-null  object
# dtypes: float64(4), int64(1), object(15)
# memory usage: 33.9+ MB

# %%
# Load the CSV file into a DataFrame
df = restaurant_data

# Specify the columns you want to keep
columns_to_keep = [
    'dba', 'boro', 'building', 'street', 'zipcode', 'phone',
    'cuisine_description', 'latitude', 'longitude'
]

# Filter the DataFrame to include only the columns of interest
df_filtered = df[columns_to_keep]

#
df_filtered_nonan = df_filtered[df_filtered['cuisine_description'].notna()]

# Drop duplicates based on the 'DBA' column
df_unique_restaurants = df_filtered_nonan.drop_duplicates(subset=['dba'])

# %%
df_brooklyn = df_unique_restaurants[df_unique_restaurants['boro'] == 'Brooklyn']
df_queens = df_unique_restaurants[df_unique_restaurants['boro'] == 'Queens']
df_manhattan = df_unique_restaurants[df_unique_restaurants['boro'] == 'Manhattan']
df_bronx = df_unique_restaurants[df_unique_restaurants['boro'] == 'Bronx']
df_statenisland = df_unique_restaurants[df_unique_restaurants['boro'] == 'Staten Island']

# %%
df_bronx_sorted = df_bronx.sort_values(by=['latitude', 'longitude'], ascending=False)
df_bronx_sorted
# Out:
#                                                       dba   boro building  \
# 3290       COLLEGE OF MOUNT SAINT VINCENT (Mag's Kitchen)  Bronx     6301
# 67407   COLLEGE OF MOUNT ST.VINCENT (HUDSON HEIGHTS; 1...  Bronx     6301
# 99666                      COLLEGE OF MOUNT SAINT VINCENT  Bronx     6301
# 54193                                 Marianne Pizza Cafe  Bronx     6100
# 2281                                   EJ'S BAKERY & CAFE  Bronx      462
# ...                                                   ...    ...      ...
# 72924                                            7 SPICES  Bronx   906908
# 85660                             GOLDEN EAGLE RESTAURANT  Bronx    97579
# 95074                     BAR & RESTAURANT EL SALVADORENO  Bronx   451455
# 105731                             CHOP-STICKS RESTAURANT  Bronx     7718
# 22073                                ENZO'S OF ARTHUR AVE  Bronx      NaN
#
#                     street  zipcode       phone cuisine_description  \
# 3290      RIVERDALE AVENUE  10471.0  7184053486          Coffee/Tea
# 67407     RIVERDALE AVENUE  10471.0  7184053486            American
# 99666     RIVERDALE AVENUE  10471.0  7184053486            American
# 54193     RIVERDALE AVENUE  10471.0  9144717274               Pizza
# 2281      WEST  261 STREET  10471.0  3479490023             Spanish
# ...                    ...      ...         ...                 ...
# 72924         E GUNHILL RD      NaN  3473268646           Caribbean
# 85660   MORRIS PARK AVENUE      NaN  7188634028            American
# 95074        MORRIS PK AVE      NaN  3478794891      Latin American
# 105731           21 AVENUE      NaN  7182048119             Chinese
# 22073           ARTHUR AVE  10458.0  7187334455             Italian
#
#          latitude  longitude
# 3290    40.912822 -73.902504
# 67407   40.912822 -73.902504
# 99666   40.912822 -73.902504
# 54193   40.910473 -73.903108
# 2281    40.910012 -73.902671
# ...           ...        ...
# 72924    0.000000   0.000000
# 85660    0.000000   0.000000
# 95074    0.000000   0.000000
# 105731   0.000000   0.000000
# 22073         NaN        NaN
#
# [1725 rows x 9 columns]

# %%
Latitude = 40.630629
Longitude = -73.966336

# %%
# Set to keep track of restaurants to be removed based on API calls or other criteria
restaurants_to_remove = set()
api_response_restaurants_list = []
index_to_skip = []

# %%
# Use iterrows() to iterate through DataFrame rows
for index, row in df_bronx_sorted.iterrows():
    if index in index_to_skip and len(index_to_skip) > 0:
      continue
    # Check if the current restaurantName is in the set of restaurants to remove
    if row['dba'] in restaurants_to_remove and len(restaurants_to_remove) > 0:
      for restaurant_name in restaurants_to_remove:
        # Check against each name in the DataFrame
        match_score = fuzz.token_set_ratio(restaurant_name, row['dba'])
        if match_score >= 60:
          matches = [(business['rating'], business['review_count']) for business in api_response_restaurants_list if business['name'] == restaurant_name]
          # Extract the rating and review count if a match is found
          if matches:
            rating, review_count = matches[0]  # Assuming only one match
            df_bronx_sorted.loc[index, 'yelp_rating'] = rating
            df_bronx_sorted.loc[index, 'yelp_review_count'] = review_count
            break
      continue  # Skip the rest of the loop and move to the next row

    # Call the API for each row's latitude and longitude not in restaurants_to_remove
    api_response_restaurants, restaurant_list = query_api(row['latitude'], row['longitude'])
    print(restaurant_list)
    print(api_response_restaurants)
    api_response_restaurants_list.extend(api_response_restaurants)
    restaurants_to_remove.update(restaurant_list)

    # Send to api_response_restaurants to Blob or anything because I want to keep those values for future references

    for restaurant_name in restaurants_to_remove:
      # Check against each name in the DataFrame
      match_score = fuzz.token_set_ratio(restaurant_name, row['dba'])
      if match_score >= 60:
        matches = [(business['rating'], business['review_count']) for business in api_response_restaurants_list if business['name'] == restaurant_name]
        # Extract the rating and review count if a match is found
        if matches:
          rating, review_count = matches[0]  # Assuming only one match
          print(f"Rating for '{restaurant_name}': {rating}")
          print(f"Review Count for '{restaurant_name}': {review_count}")
          df_bronx_sorted.loc[index, 'yelp_rating'] = rating
          df_bronx_sorted.loc[index, 'yelp_review_count'] = review_count
          break
    index_to_skip.append(index)
# Out:
# ['XingLong', 'Fulton Cafe', 'City Gourmet Deli']
# [{'id': '2S7AZXymi4xgmcM0XW8mTw', 'alias': 'xinglong-bronx-2', 'name': 'XingLong', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oIfBLKXGH-z45gzyMlLSEQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/xinglong-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 3, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 4.0, 'coordinates': {'latitude': 40.8325, 'longitude': -73.90401}, 'transactions': ['delivery'], 'price': '$$$$', 'location': {'address1': '553 E 169th St', 'address2': None, 'address3': None, 'city': 'Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['553 E 169th St', 'Bronx, NY 10456']}, 'phone': '+17182938888', 'display_phone': '(718) 293-8888', 'distance': 92.09804335143308, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'xZ55Y6m9rUPHeYf0yZr-Tg', 'alias': 'fulton-cafe-bronx-2', 'name': 'Fulton Cafe', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JJ7GfXi2RiGLJN7gWRj-sQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/fulton-cafe-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 2, 'categories': [{'alias': 'cafes', 'title': 'Cafes'}], 'rating': 5.0, 'coordinates': {'latitude': 40.83143, 'longitude': -73.90317}, 'transactions': [], 'location': {'address1': '1276 Fulton Ave', 'address2': '', 'address3': 'Bronx-Lebanon Hospital Center', 'city': 'Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['1276 Fulton Ave', 'Bronx-Lebanon Hospital Center', 'Bronx, NY 10456']}, 'phone': '+17189018926', 'display_phone': '(718) 901-8926', 'distance': 79.59743501264865, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'bBSeXkwfjm-02g2f0W5UGg', 'alias': 'city-gourmet-deli-the-bronx', 'name': 'City Gourmet Deli', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gaNcQNBok2UjUWIOMIrI2A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/city-gourmet-deli-the-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 1, 'categories': [{'alias': 'delis', 'title': 'Delis'}], 'rating': 5.0, 'coordinates': {'latitude': 40.8321, 'longitude': -73.90329}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '568 E 169 St', 'address2': None, 'address3': '', 'city': 'The Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['568 E 169 St', 'The Bronx, NY 10456']}, 'phone': '+17184503455', 'display_phone': '(718) 450-3455', 'distance': 28.795482569248737, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}]
# Rating for 'Churrasco Del Valle': 0.0
# Review Count for 'Churrasco Del Valle': 0
# ["Willie's Steak House", "John's Diner", 'The South Of France', 'Pupuseria Salvadoreña', 'Cachapa Cachapa', 'Estrellita Mixteca', 'Dragon Village', 'New One Chinese Restaurant', 'Sabrosura Pizzeria', 'Lupes Place', '4K Deli Grocery Corporation', 'Avocado Gourmet Deli']
# [{'id': 'uOKv62ooXVVBR69ZmlWo2A', 'alias': 'willies-steak-house-bronx-2', 'name': "Willie's Steak House", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rz2vPdiWQSI7xZSBtwNLjA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/willies-steak-house-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 65, 'categories': [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 3.0, 'coordinates': {'latitude': 40.83214, 'longitude': -73.8649}, 'transactions': ['pickup'], 'price': '$$', 'location': {'address1': '1832 Westchester Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1832 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17188229697', 'display_phone': '(718) 822-9697', 'distance': 81.96266149845057, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://www.williessteakhousebronx.com/menu.html', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'e2IhIYuNNppIFGI_CHy7bA', 'alias': 'johns-diner-bronx', 'name': "John's Diner", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXOW-RaQaXc9Flf3AQ8FKQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/johns-diner-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 37, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'diners', 'title': 'Diners'}], 'rating': 3.5, 'coordinates': {'latitude': 40.83156, 'longitude': -73.86687}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1786 Westchester Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1786 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17189319402', 'display_phone': '(718) 931-9402', 'distance': 107.06965555918731, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '_8YjW7o5BzD7iFbLkDhQjg', 'alias': 'the-south-of-france-bronx', 'name': 'The South Of France', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sypsenSvDzbeqWcNzLG-yg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-south-of-france-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 34, 'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 4.4, 'coordinates': {'latitude': 40.8316668252024, 'longitude': -73.86611349117314}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1800 Westchester Ave', 'address2': None, 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1800 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17188231133', 'display_phone': '(718) 823-1133', 'distance': 48.573740850993026, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '1jTtw6l85Ywq3QqvXGxBeg', 'alias': 'pupuseria-salvadoreña-bronx', 'name': 'Pupuseria Salvadoreña', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lgGfPN4cAjXqPSjOPfDl5w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pupuseria-salvadore%C3%B1a-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 26, 'categories': [{'alias': 'salvadoran', 'title': 'Salvadoran'}], 'rating': 3.8, 'coordinates': {'latitude': 40.8321599931289, 'longitude': -73.8651540258206}, 'transactions': [], 'price': '$$', 'location': {'address1': '1824 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'count ...
# Rating for 'Estrella Mexicana': 2.9
# Review Count for 'Estrella Mexicana': 19
# ['Brisas Del Caribe', 'Empire Wok', 'Marisco Centro Seafood Restaurant & Fish Market', 'Vegan Grill', "Lulu's Luncheonette", 'Ranch Jamaican Restaurant', 'Q44 Bar and Grill', 'My Deli Gourmet & Grill', 'Sing Garden Restaurant', 'Wuarache Restaurant', 'Saba Quality Plus Deli', 'Vegan Hub', "Gino T's Pizza", 'Amber Restaurant']
# [{'id': 'voSYlJnDLePsAFTqT7p3PA', 'alias': 'brisas-del-caribe-bronx', 'name': 'Brisas Del Caribe', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c9J2CU752m-GTFoeuZUqTw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/brisas-del-caribe-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 217, 'categories': [{'alias': 'dominican', 'title': 'Dominican'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 3.6, 'coordinates': {'latitude': 40.83214364582247, 'longitude': -73.85134853272807}, 'transactions': ['pickup'], 'price': '$', 'location': {'address1': '1207 Castle Hill Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10462', 'country': 'US', 'state': 'NY', 'display_address': ['1207 Castle Hill Ave', 'Bronx, NY 10462']}, 'phone': '+17187949710', 'display_phone': '(718) 794-9710', 'distance': 27.857960497344127, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'F1n2EAqybwEXdEoQQD8tnA', 'alias': 'empire-wok-new-york-2', 'name': 'Empire Wok', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9A4tef20hwJZLjiSVhD_NA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/empire-wok-new-york-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 41, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 2.8, 'coordinates': {'latitude': 40.832786, 'longitude': -73.850914}, 'transactions': [], 'price': '$', 'location': {'address1': '1230 Castle Hill Ave', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10462', 'country': 'US', 'state': 'NY', 'display_address': ['1230 Castle Hill Ave', 'New York, NY 10462']}, 'phone': '+17188282919', 'display_phone': '(718) 828-2919', 'distance': 84.76170606674427, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://empire1230.m988.com/order/menu.aspx', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'cwIoutoDgdqTzNXlHDRYrQ', 'alias': 'marisco-centro-seafood-restaurant-and-fish-market-bronx-3', 'name': 'Marisco Centro Seafood Restaurant & Fish Market', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S9hsLXFokv5yhv_7YHX7Wg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/marisco-centro-seafood-restaurant-and-fish-market-bronx-3?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 40, 'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}], 'rating': 2.5, 'coordinates': {'latitude': 40.83156, 'longitude': -73.85095}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1160 Castle Hill Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10462', 'country': 'US', 'state': 'NY', 'display_address': ['1160 Castle Hill Ave', 'Bronx, NY 10462']}, 'phone': '+17187920500', 'display_phone': '(718) 792-0500', 'distance': 53.08031033233988, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'pI-aETYVrGd34LF-UTot9A', 'alias': 'vegan-grill-the-bronx', 'name': 'Vegan Grill', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2kizDM6oMuTc_PBBx5hmaA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/vegan-grill-the-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 36, 'categories': [{'alias': 'falafel', 'title': 'Falafel'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 3.9, 'coordinates': {'latitude': 40.831996, 'longitude': -73.851316}, 't ...
# Rating for 'Sabrosura Pizzeria': 3.8
# Review Count for 'Sabrosura Pizzeria': 4
# ['Mama Puebla', 'Lena Trattoria', 'Healthy Fresh', 'Pizza Hut', 'Empire Express', 'T.ology', 'El Paisano Pizza & Pasta', 'Daisys Pizza Palace', "Delponte's Pizzeria", 'Pal Deli And Grocery']
# [{'id': 'pSJGPVjAyKb7EXGZkqLzvg', 'alias': 'mama-puebla-bronx', 'name': 'Mama Puebla', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Qdc9WIp-EzlUst9SLsJ5IA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mama-puebla-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 99, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}], 'rating': 3.7, 'coordinates': {'latitude': 40.831959, 'longitude': -73.827011}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '3465 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['3465 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17187926262', 'display_phone': '(718) 792-6262', 'distance': 28.02693503967209, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'kPOSj-eej3acPMIc5vfYSQ', 'alias': 'lena-trattoria-bronx', 'name': 'Lena Trattoria', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MDrFKE7msBi1lB1u1dBrxQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/lena-trattoria-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 44, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'pastashops', 'title': 'Pasta Shops'}, {'alias': 'italian', 'title': 'Italian'}], 'rating': 4.5, 'coordinates': {'latitude': 40.831575, 'longitude': -73.827269}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '3470 E Tremont Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['3470 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17182395362', 'display_phone': '(718) 239-5362', 'distance': 42.54978956853897, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://lenatrattoria.com/menu/', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'bbENghLOb8TOnY4B2TU4MA', 'alias': 'healthy-fresh-the-bronx-2', 'name': 'Healthy Fresh', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GhFy4NFLhML5u3FBeZaa7A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/healthy-fresh-the-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 17, 'categories': [{'alias': 'salad', 'title': 'Salad'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'steak', 'title': 'Steakhouses'}], 'rating': 3.3, 'coordinates': {'latitude': 40.832361, 'longitude': -73.82811}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '3432 E Tremont Ave', 'address2': 'Ste 3', 'address3': None, 'city': 'The Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['3432 E Tremont Ave', 'Ste 3', 'The Bronx, NY 10465']}, 'phone': '+17185766973', 'display_phone': '(718) 576-6973', 'distance': 82.06114360945756, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://gohealthyfresh.com/menu/', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'F9Qbn8ORn6zA7m2x6Bin3g', 'alias': 'pizza-hut-bronx-17', 'name': 'Pizza Hut', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FLUM8U1-f1Pyl83lbFmHaA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pizza-hut-bronx-17?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 8, 'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'pizza', 'title': 'Pizza'}], 'rating': 2.8, 'coordinates': {'latitude': 40.83278, 'longitude': -73.8278}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '3429 E Tremont  ...
# Rating for 'Juice Rite': 3.4
# Review Count for 'Juice Rite': 34
# ["Willie's Steak House", "John's Diner", 'The South Of France', 'Pupuseria Salvadoreña', 'Cachapa Cachapa', 'Estrellita Mixteca', 'Dragon Village', 'New One Chinese Restaurant', 'Sabrosura Pizzeria', 'Lupes Place', 'Avocado Gourmet Deli']
# [{'id': 'uOKv62ooXVVBR69ZmlWo2A', 'alias': 'willies-steak-house-bronx-2', 'name': "Willie's Steak House", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rz2vPdiWQSI7xZSBtwNLjA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/willies-steak-house-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 65, 'categories': [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 3.0, 'coordinates': {'latitude': 40.83214, 'longitude': -73.8649}, 'transactions': ['pickup'], 'price': '$$', 'location': {'address1': '1832 Westchester Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1832 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17188229697', 'display_phone': '(718) 822-9697', 'distance': 99.65824422108385, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://www.williessteakhousebronx.com/menu.html', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'e2IhIYuNNppIFGI_CHy7bA', 'alias': 'johns-diner-bronx', 'name': "John's Diner", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXOW-RaQaXc9Flf3AQ8FKQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/johns-diner-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 37, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'diners', 'title': 'Diners'}], 'rating': 3.5, 'coordinates': {'latitude': 40.83156, 'longitude': -73.86687}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1786 Westchester Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1786 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17189319402', 'display_phone': '(718) 931-9402', 'distance': 88.19726738723452, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '_8YjW7o5BzD7iFbLkDhQjg', 'alias': 'the-south-of-france-bronx', 'name': 'The South Of France', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sypsenSvDzbeqWcNzLG-yg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-south-of-france-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 34, 'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 4.4, 'coordinates': {'latitude': 40.8316668252024, 'longitude': -73.86611349117314}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1800 Westchester Ave', 'address2': None, 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1800 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17188231133', 'display_phone': '(718) 823-1133', 'distance': 33.7000250564686, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '1jTtw6l85Ywq3QqvXGxBeg', 'alias': 'pupuseria-salvadoreña-bronx', 'name': 'Pupuseria Salvadoreña', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lgGfPN4cAjXqPSjOPfDl5w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pupuseria-salvadore%C3%B1a-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 26, 'categories': [{'alias': 'salvadoran', 'title': 'Salvadoran'}], 'rating': 3.8, 'coordinates': {'latitude': 40.8321599931289, 'longitude': -73.8651540258206}, 'transactions': [], 'price': '$$', 'location': {'address1': '1824 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country' ...
# Rating for 'Ogden Restaurant': 0.0
# Review Count for 'Ogden Restaurant': 0
# ["John's Diner", 'The South Of France', 'Pupuseria Salvadoreña', 'Cachapa Cachapa', 'Estrellita Mixteca', 'Dragon Village', 'New One Chinese Restaurant', 'Sabrosura Pizzeria', 'Lupes Place', 'Avocado Gourmet Deli']
# [{'id': 'e2IhIYuNNppIFGI_CHy7bA', 'alias': 'johns-diner-bronx', 'name': "John's Diner", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXOW-RaQaXc9Flf3AQ8FKQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/johns-diner-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 37, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'diners', 'title': 'Diners'}], 'rating': 3.5, 'coordinates': {'latitude': 40.83156, 'longitude': -73.86687}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1786 Westchester Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1786 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17189319402', 'display_phone': '(718) 931-9402', 'distance': 82.88036928460461, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '_8YjW7o5BzD7iFbLkDhQjg', 'alias': 'the-south-of-france-bronx', 'name': 'The South Of France', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sypsenSvDzbeqWcNzLG-yg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-south-of-france-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 34, 'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 4.4, 'coordinates': {'latitude': 40.8316668252024, 'longitude': -73.86611349117314}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1800 Westchester Ave', 'address2': None, 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1800 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17188231133', 'display_phone': '(718) 823-1133', 'distance': 32.28155077020386, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '1jTtw6l85Ywq3QqvXGxBeg', 'alias': 'pupuseria-salvadoreña-bronx', 'name': 'Pupuseria Salvadoreña', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lgGfPN4cAjXqPSjOPfDl5w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pupuseria-salvadore%C3%B1a-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 26, 'categories': [{'alias': 'salvadoran', 'title': 'Salvadoran'}], 'rating': 3.8, 'coordinates': {'latitude': 40.8321599931289, 'longitude': -73.8651540258206}, 'transactions': [], 'price': '$$', 'location': {'address1': '1824 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1824 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17184094013', 'display_phone': '(718) 409-4013', 'distance': 81.3043478885205, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'ow5iKyflDJcjAWoylTP7cA', 'alias': 'cachapa-cachapa-bronx-3', 'name': 'Cachapa Cachapa', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/URhpD-3gfFzshP4fLX-qWQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/cachapa-cachapa-bronx-3?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 22, 'categories': [{'alias': 'venezuelan', 'title': 'Venezuelan'}, {'alias': 'dominican', 'title': 'Dominican'}], 'rating': 3.7, 'coordinates': {'latitude': 40.83213, 'longitude': -73.86606}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '1805 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1805 Westcheste ...
# Rating for 'Cachapa Cachapa': 3.7
# Review Count for 'Cachapa Cachapa': 22
# ['Mama Puebla', 'Lena Trattoria', 'Healthy Fresh', 'Pizza Hut', 'Empire Express', 'T.ology', 'El Paisano Pizza & Pasta', 'Daisys Pizza Palace', "Delponte's Pizzeria", 'Pal Deli And Grocery']
# [{'id': 'pSJGPVjAyKb7EXGZkqLzvg', 'alias': 'mama-puebla-bronx', 'name': 'Mama Puebla', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Qdc9WIp-EzlUst9SLsJ5IA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mama-puebla-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 99, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}], 'rating': 3.7, 'coordinates': {'latitude': 40.831959, 'longitude': -73.827011}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '3465 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['3465 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17187926262', 'display_phone': '(718) 792-6262', 'distance': 25.96191044654295, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'kPOSj-eej3acPMIc5vfYSQ', 'alias': 'lena-trattoria-bronx', 'name': 'Lena Trattoria', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MDrFKE7msBi1lB1u1dBrxQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/lena-trattoria-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 44, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'pastashops', 'title': 'Pasta Shops'}, {'alias': 'italian', 'title': 'Italian'}], 'rating': 4.5, 'coordinates': {'latitude': 40.831575, 'longitude': -73.827269}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '3470 E Tremont Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['3470 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17182395362', 'display_phone': '(718) 239-5362', 'distance': 38.93547167865387, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://lenatrattoria.com/menu/', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'bbENghLOb8TOnY4B2TU4MA', 'alias': 'healthy-fresh-the-bronx-2', 'name': 'Healthy Fresh', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GhFy4NFLhML5u3FBeZaa7A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/healthy-fresh-the-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 17, 'categories': [{'alias': 'salad', 'title': 'Salad'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'steak', 'title': 'Steakhouses'}], 'rating': 3.3, 'coordinates': {'latitude': 40.832361, 'longitude': -73.82811}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '3432 E Tremont Ave', 'address2': 'Ste 3', 'address3': None, 'city': 'The Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['3432 E Tremont Ave', 'Ste 3', 'The Bronx, NY 10465']}, 'phone': '+17185766973', 'display_phone': '(718) 576-6973', 'distance': 85.66868498139836, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://gohealthyfresh.com/menu/', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'F9Qbn8ORn6zA7m2x6Bin3g', 'alias': 'pizza-hut-bronx-17', 'name': 'Pizza Hut', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FLUM8U1-f1Pyl83lbFmHaA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pizza-hut-bronx-17?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 8, 'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'pizza', 'title': 'Pizza'}], 'rating': 2.8, 'coordinates': {'latitude': 40.83278, 'longitude': -73.8278}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '3429 E Tremont  ...
# Rating for 'Mama Puebla': 3.7
# Review Count for 'Mama Puebla': 99
# ['Fulton Cafe', 'City Gourmet Deli', 'Stop One Deli']
# [{'id': 'xZ55Y6m9rUPHeYf0yZr-Tg', 'alias': 'fulton-cafe-bronx-2', 'name': 'Fulton Cafe', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JJ7GfXi2RiGLJN7gWRj-sQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/fulton-cafe-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 2, 'categories': [{'alias': 'cafes', 'title': 'Cafes'}], 'rating': 5.0, 'coordinates': {'latitude': 40.83143, 'longitude': -73.90317}, 'transactions': [], 'location': {'address1': '1276 Fulton Ave', 'address2': '', 'address3': 'Bronx-Lebanon Hospital Center', 'city': 'Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['1276 Fulton Ave', 'Bronx-Lebanon Hospital Center', 'Bronx, NY 10456']}, 'phone': '+17189018926', 'display_phone': '(718) 901-8926', 'distance': 42.094740037161586, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'bBSeXkwfjm-02g2f0W5UGg', 'alias': 'city-gourmet-deli-the-bronx', 'name': 'City Gourmet Deli', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gaNcQNBok2UjUWIOMIrI2A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/city-gourmet-deli-the-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 1, 'categories': [{'alias': 'delis', 'title': 'Delis'}], 'rating': 5.0, 'coordinates': {'latitude': 40.8321, 'longitude': -73.90329}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '568 E 169 St', 'address2': None, 'address3': '', 'city': 'The Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['568 E 169 St', 'The Bronx, NY 10456']}, 'phone': '+17184503455', 'display_phone': '(718) 450-3455', 'distance': 71.27232863532966, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '9d2oQoGRN9O8UEXKe1pUOg', 'alias': 'stop-one-deli-bronx', 'name': 'Stop One Deli', 'image_url': '', 'is_closed': False, 'url': 'https://www.yelp.com/biz/stop-one-deli-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 0, 'categories': [{'alias': 'delis', 'title': 'Delis'}], 'rating': 0.0, 'coordinates': {'latitude': 40.83173, 'longitude': -73.9016538}, 'transactions': [], 'location': {'address1': '621 E 169th St', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['621 E 169th St', 'Bronx, NY 10456']}, 'phone': '+17188932064', 'display_phone': '(718) 893-2064', 'distance': 83.78101735238518, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}]
# Rating for 'Ogden Restaurant': 0.0
# Review Count for 'Ogden Restaurant': 0
# ["John's Diner", 'The South Of France', 'Pupuseria Salvadoreña', 'Cachapa Cachapa', 'Estrellita Mixteca', 'Dragon Village', 'Sabrosura Pizzeria', 'Mr Taco Grande', 'Lupes Place', 'Avocado Gourmet Deli']
# [{'id': 'e2IhIYuNNppIFGI_CHy7bA', 'alias': 'johns-diner-bronx', 'name': "John's Diner", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXOW-RaQaXc9Flf3AQ8FKQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/johns-diner-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 37, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'diners', 'title': 'Diners'}], 'rating': 3.5, 'coordinates': {'latitude': 40.83156, 'longitude': -73.86687}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1786 Westchester Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1786 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17189319402', 'display_phone': '(718) 931-9402', 'distance': 76.12425473662007, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '_8YjW7o5BzD7iFbLkDhQjg', 'alias': 'the-south-of-france-bronx', 'name': 'The South Of France', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sypsenSvDzbeqWcNzLG-yg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-south-of-france-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 34, 'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 4.4, 'coordinates': {'latitude': 40.8316668252024, 'longitude': -73.86611349117314}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1800 Westchester Ave', 'address2': None, 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1800 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17188231133', 'display_phone': '(718) 823-1133', 'distance': 28.356413075095606, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '1jTtw6l85Ywq3QqvXGxBeg', 'alias': 'pupuseria-salvadoreña-bronx', 'name': 'Pupuseria Salvadoreña', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lgGfPN4cAjXqPSjOPfDl5w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pupuseria-salvadore%C3%B1a-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 26, 'categories': [{'alias': 'salvadoran', 'title': 'Salvadoran'}], 'rating': 3.8, 'coordinates': {'latitude': 40.8321599931289, 'longitude': -73.8651540258206}, 'transactions': [], 'price': '$$', 'location': {'address1': '1824 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1824 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17184094013', 'display_phone': '(718) 409-4013', 'distance': 87.6989238307254, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'ow5iKyflDJcjAWoylTP7cA', 'alias': 'cachapa-cachapa-bronx-3', 'name': 'Cachapa Cachapa', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/URhpD-3gfFzshP4fLX-qWQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/cachapa-cachapa-bronx-3?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 22, 'categories': [{'alias': 'venezuelan', 'title': 'Venezuelan'}, {'alias': 'dominican', 'title': 'Dominican'}], 'rating': 3.7, 'coordinates': {'latitude': 40.83213, 'longitude': -73.86606}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '1805 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1805 Westchest ...
# Rating for 'Ogden Restaurant': 0.0
# Review Count for 'Ogden Restaurant': 0
# ["John's Diner", 'The South Of France', 'Pupuseria Salvadoreña', 'Cachapa Cachapa', 'Estrellita Mixteca', 'Dragon Village', 'Golden Flower Chinese Restaurant', 'Sabrosura Pizzeria', 'Mr Taco Grande', 'Lian Xi Ming', 'Lupes Place', 'Avocado Gourmet Deli']
# [{'id': 'e2IhIYuNNppIFGI_CHy7bA', 'alias': 'johns-diner-bronx', 'name': "John's Diner", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXOW-RaQaXc9Flf3AQ8FKQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/johns-diner-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 37, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'diners', 'title': 'Diners'}], 'rating': 3.5, 'coordinates': {'latitude': 40.83156, 'longitude': -73.86687}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1786 Westchester Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1786 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17189319402', 'display_phone': '(718) 931-9402', 'distance': 70.08227913297027, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '_8YjW7o5BzD7iFbLkDhQjg', 'alias': 'the-south-of-france-bronx', 'name': 'The South Of France', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sypsenSvDzbeqWcNzLG-yg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-south-of-france-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 34, 'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 4.4, 'coordinates': {'latitude': 40.8316668252024, 'longitude': -73.86611349117314}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1800 Westchester Ave', 'address2': None, 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1800 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17188231133', 'display_phone': '(718) 823-1133', 'distance': 27.183463957827968, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '1jTtw6l85Ywq3QqvXGxBeg', 'alias': 'pupuseria-salvadoreña-bronx', 'name': 'Pupuseria Salvadoreña', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lgGfPN4cAjXqPSjOPfDl5w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pupuseria-salvadore%C3%B1a-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 26, 'categories': [{'alias': 'salvadoran', 'title': 'Salvadoran'}], 'rating': 3.8, 'coordinates': {'latitude': 40.8321599931289, 'longitude': -73.8651540258206}, 'transactions': [], 'price': '$$', 'location': {'address1': '1824 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1824 Westchester Ave', 'Bronx, NY 10472']}, 'phone': '+17184094013', 'display_phone': '(718) 409-4013', 'distance': 93.94659204000698, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'ow5iKyflDJcjAWoylTP7cA', 'alias': 'cachapa-cachapa-bronx-3', 'name': 'Cachapa Cachapa', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/URhpD-3gfFzshP4fLX-qWQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/cachapa-cachapa-bronx-3?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 22, 'categories': [{'alias': 'venezuelan', 'title': 'Venezuelan'}, {'alias': 'dominican', 'title': 'Dominican'}], 'rating': 3.7, 'coordinates': {'latitude': 40.83213, 'longitude': -73.86606}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '1805 Westchester Ave', 'address2': '', 'address3': None, 'city': 'Bronx', 'zip_code': '10472', 'country': 'US', 'state': 'NY', 'display_address': ['1805 Westches ...
# Rating for 'The South Of France': 4.4
# Review Count for 'The South Of France': 34
# ['Fulton Cafe', 'City Gourmet Deli', 'Stop One Deli']
# [{'id': 'xZ55Y6m9rUPHeYf0yZr-Tg', 'alias': 'fulton-cafe-bronx-2', 'name': 'Fulton Cafe', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JJ7GfXi2RiGLJN7gWRj-sQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/fulton-cafe-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 2, 'categories': [{'alias': 'cafes', 'title': 'Cafes'}], 'rating': 5.0, 'coordinates': {'latitude': 40.83143, 'longitude': -73.90317}, 'transactions': [], 'location': {'address1': '1276 Fulton Ave', 'address2': '', 'address3': 'Bronx-Lebanon Hospital Center', 'city': 'Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['1276 Fulton Ave', 'Bronx-Lebanon Hospital Center', 'Bronx, NY 10456']}, 'phone': '+17189018926', 'display_phone': '(718) 901-8926', 'distance': 31.52967169700136, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'bBSeXkwfjm-02g2f0W5UGg', 'alias': 'city-gourmet-deli-the-bronx', 'name': 'City Gourmet Deli', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gaNcQNBok2UjUWIOMIrI2A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/city-gourmet-deli-the-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 1, 'categories': [{'alias': 'delis', 'title': 'Delis'}], 'rating': 5.0, 'coordinates': {'latitude': 40.8321, 'longitude': -73.90329}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '568 E 169 St', 'address2': None, 'address3': '', 'city': 'The Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['568 E 169 St', 'The Bronx, NY 10456']}, 'phone': '+17184503455', 'display_phone': '(718) 450-3455', 'distance': 92.33140963132526, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': '9d2oQoGRN9O8UEXKe1pUOg', 'alias': 'stop-one-deli-bronx', 'name': 'Stop One Deli', 'image_url': '', 'is_closed': False, 'url': 'https://www.yelp.com/biz/stop-one-deli-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 0, 'categories': [{'alias': 'delis', 'title': 'Delis'}], 'rating': 0.0, 'coordinates': {'latitude': 40.83173, 'longitude': -73.9016538}, 'transactions': [], 'location': {'address1': '621 E 169th St', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10456', 'country': 'US', 'state': 'NY', 'display_address': ['621 E 169th St', 'Bronx, NY 10456']}, 'phone': '+17188932064', 'display_phone': '(718) 893-2064', 'distance': 62.7530560375069, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}]
# Rating for 'Frenchy's Bar & Restaurant': 0.0
# Review Count for 'Frenchy's Bar & Restaurant': 0
# []
# []
# ["John's Diner", 'The South Of France', 'Cachapa Cachapa', 'Estrellita Mixteca', 'Dragon Village', 'Golden Flower Chinese Restaurant', 'Sabrosura Pizzeria', 'Guate Linda Restaurant & Bakery', 'Mr Taco Grande', 'Lian Xi Ming', 'Lupes Place', 'Avocado Gourmet Deli', 'Stop for Shop']
# ...
# Rating for 'Flavas restaurant and lounge': 2.6
# Review Count for 'Flavas restaurant and lounge': 71
# ['Glen Roy Bar', 'Popeyes Louisiana Kitchen', 'Burger King', 'Mister Pizza Lizette Dollar Pizza', 'Chipotle Mexican Grill', 'Ocky Fried Chicken & Pizza', 'Express Deli', 'S & D', '153 Deli', 'Lincoln Fried Chicken']
# [{'id': '_UNgoCWZtfyL_8J-1OPxHQ', 'alias': 'glen-roy-bar-bronx-2', 'name': 'Glen Roy Bar', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RTAce679pqDkvEWUwcP7fg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/glen-roy-bar-bronx-2?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 18, 'categories': [{'alias': 'tradamerican', 'title': 'American'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'salad', 'title': 'Salad'}], 'rating': 4.1, 'coordinates': {'latitude': 40.81891304227314, 'longitude': -73.92794014129477}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '145 E 149th St', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10451', 'country': 'US', 'state': 'NY', 'display_address': ['145 E 149th St', 'Bronx, NY 10451']}, 'phone': '+17189939804', 'display_phone': '(718) 993-9804', 'distance': 47.066441351865954, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'G97CYDJF4kHhsWDHOxEuWQ', 'alias': 'popeyes-louisiana-kitchen-bronx-15', 'name': 'Popeyes Louisiana Kitchen', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4CihxnHyssO5dYFKLL5jhw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/popeyes-louisiana-kitchen-bronx-15?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 12, 'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'hotdogs', 'title': 'Fast Food'}], 'rating': 2.7, 'coordinates': {'latitude': 40.819074, 'longitude': -73.927417}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '557 Grand Concourse', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10451', 'country': 'US', 'state': 'NY', 'display_address': ['557 Grand Concourse', 'Bronx, NY 10451']}, 'phone': '+17187086650', 'display_phone': '(718) 708-6650', 'distance': 93.6316013708552, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://popeyes.com/menu', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'Ml3Xfm11NI30BER9LD0hkg', 'alias': 'burger-king-bronx-14', 'name': 'Burger King', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9bebwyxV-TFn2dn5Z70rYA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/burger-king-bronx-14?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 4, 'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}], 'rating': 3.8, 'coordinates': {'latitude': 40.8190183, 'longitude': -73.9273136}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '557 Grand Concourse', 'address2': None, 'address3': None, 'city': 'Bronx', 'zip_code': '10451', 'country': 'US', 'state': 'NY', 'display_address': ['557 Grand Concourse', 'Bronx, NY 10451']}, 'phone': '+17187086651', 'display_phone': '(718) 708-6651', 'distance': 100.90139609294371, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'ul736Bd9-ZdUeWgAJAZ1Fg', 'alias': 'mister-pizza-lizette-dollar-pizza-west-bronx', 'name': 'Mister Pizza Lizette Dollar Pizza', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n522j_uHqXZEWDv9yVfRYA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mister-pizza-lizette-dollar-pizza-west-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 3, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'food', 'title': 'Food'}, {'alias': 'hotdogs', 'title': 'Fast Food'}], 'rating': 2.3, 'coordinates': {'latitude': 40.8188889386495, 'longitude': -73.9277797948618}, 'trans ...
# Rating for 'Mya’s Bar & Kitchen': 3.9
# Review Count for 'Mya’s Bar & Kitchen': 15
# ['Eleven Star', 'Mamar Bari Indian Cuisine']
# [{'id': 'Bm8kp5oEE4wN6PjRj-v6UA', 'alias': 'eleven-star-woodstock', 'name': 'Eleven Star', 'image_url': '', 'is_closed': False, 'url': 'https://www.yelp.com/biz/eleven-star-woodstock?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 1, 'categories': [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 1.0, 'coordinates': {'latitude': 40.8188095, 'longitude': -73.9143524}, 'transactions': [], 'location': {'address1': '2985 3rd Ave', 'address2': '', 'address3': '', 'city': 'Woodstock', 'zip_code': '10455', 'country': 'US', 'state': 'NY', 'display_address': ['2985 3rd Ave', 'Woodstock, NY 10455']}, 'phone': '+19174736999', 'display_phone': '(917) 473-6999', 'distance': 19.731370189307782, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://11starrestaurant.com/ul.sf-menu', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'TIENlElG8TfYW1Scar6UpQ', 'alias': 'mamar-bari-indian-cuisine-new-york', 'name': 'Mamar Bari Indian Cuisine', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yh2wPJJZXj4WS_j7I41lOQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mamar-bari-indian-cuisine-new-york?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 0, 'categories': [{'alias': 'indpak', 'title': 'Indian'}], 'rating': 0.0, 'coordinates': {'latitude': 40.818109, 'longitude': -73.914566}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '2960 Third Ave', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10455', 'country': 'US', 'state': 'NY', 'display_address': ['2960 Third Ave', 'New York, NY 10455']}, 'phone': '+18458363203', 'display_phone': '(845) 836-3203', 'distance': 91.60461682011531, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}]
# Rating for 'African Grill': 3.0
# Review Count for 'African Grill': 2
# ['Muscle Maker Grill', 'Wicked Wolf Bronx', 'Green Dragon Restaurant', "Frank's Pizza", 'Hawaii Chinese Restaurant']
# [{'id': '1lU3jq0jI527nlRC-aTKXg', 'alias': 'muscle-maker-grill-bronx', 'name': 'Muscle Maker Grill', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KDjZseS8hsNvdGaCu98qeA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/muscle-maker-grill-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 135, 'categories': [{'alias': 'newamerican', 'title': 'New American'}], 'rating': 3.7, 'coordinates': {'latitude': 40.8195, 'longitude': -73.8171}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '4041 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['4041 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17188226991', 'display_phone': '(718) 822-6991', 'distance': 76.29154595974907, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://www.musclemakergrill.com/menus/_menu.pdf', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'EkQAH2HOwl7NAW0YJD2bHQ', 'alias': 'wicked-wolf-bronx-bronx', 'name': 'Wicked Wolf Bronx', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eT56VDJQNoLFrYLkNCmkbg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/wicked-wolf-bronx-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 132, 'categories': [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'german', 'title': 'German'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.0, 'coordinates': {'latitude': 40.81964768677489, 'longitude': -73.8173475}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '4029 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['4029 E Tremont Ave', 'New York, NY 10465']}, 'phone': '+17188294400', 'display_phone': '(718) 829-4400', 'distance': 94.31325440706424, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://www.wickedwolfbronx.com/menu', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'W-jUQk8h_77HLQVrArsFBQ', 'alias': 'green-dragon-restaurant-bronx', 'name': 'Green Dragon Restaurant', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T7scZhMLIRnht4id5xBvSQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/green-dragon-restaurant-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 89, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'soup', 'title': 'Soup'}], 'rating': 2.9, 'coordinates': {'latitude': 40.818876, 'longitude': -73.816705}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '4111 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['4111 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17185973600', 'display_phone': '(718) 597-3600', 'distance': 34.98870829667321, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'grqE-FeOSR1vRo4T-CU9kw', 'alias': 'franks-pizza-bronx', 'name': "Frank's Pizza", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yKuZa_re5dsPjWj4xCn98g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/franks-pizza-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 43, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 3.4, 'coordinates': {'latitude': 40.81876, 'longitude': -73.8173}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '4106 E Tremont Ave', 'address2': '' ...
# Rating for 'El Barrio': 3.0
# Review Count for 'El Barrio': 1
# ['Muscle Maker Grill', 'Wicked Wolf Bronx', 'Green Dragon Restaurant', "Frank's Pizza", 'Hawaii Chinese Restaurant']
# [{'id': '1lU3jq0jI527nlRC-aTKXg', 'alias': 'muscle-maker-grill-bronx', 'name': 'Muscle Maker Grill', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KDjZseS8hsNvdGaCu98qeA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/muscle-maker-grill-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 135, 'categories': [{'alias': 'newamerican', 'title': 'New American'}], 'rating': 3.7, 'coordinates': {'latitude': 40.8195, 'longitude': -73.8171}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '4041 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['4041 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17188226991', 'display_phone': '(718) 822-6991', 'distance': 83.23281409438262, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://www.musclemakergrill.com/menus/_menu.pdf', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'EkQAH2HOwl7NAW0YJD2bHQ', 'alias': 'wicked-wolf-bronx-bronx', 'name': 'Wicked Wolf Bronx', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eT56VDJQNoLFrYLkNCmkbg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/wicked-wolf-bronx-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 132, 'categories': [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'german', 'title': 'German'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.0, 'coordinates': {'latitude': 40.81964768677489, 'longitude': -73.8173475}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '4029 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['4029 E Tremont Ave', 'New York, NY 10465']}, 'phone': '+17188294400', 'display_phone': '(718) 829-4400', 'distance': 101.89561619865253, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://www.wickedwolfbronx.com/menu', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'W-jUQk8h_77HLQVrArsFBQ', 'alias': 'green-dragon-restaurant-bronx', 'name': 'Green Dragon Restaurant', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T7scZhMLIRnht4id5xBvSQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/green-dragon-restaurant-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 89, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'soup', 'title': 'Soup'}], 'rating': 2.9, 'coordinates': {'latitude': 40.818876, 'longitude': -73.816705}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '4111 E Tremont Ave', 'address2': '', 'address3': '', 'city': 'Bronx', 'zip_code': '10465', 'country': 'US', 'state': 'NY', 'display_address': ['4111 E Tremont Ave', 'Bronx, NY 10465']}, 'phone': '+17185973600', 'display_phone': '(718) 597-3600', 'distance': 33.852867759529765, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'grqE-FeOSR1vRo4T-CU9kw', 'alias': 'franks-pizza-bronx', 'name': "Frank's Pizza", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yKuZa_re5dsPjWj4xCn98g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/franks-pizza-bronx?adjust_creative=bwRCjbHZyClcjCZ8VSlXnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bwRCjbHZyClcjCZ8VSlXnA', 'review_count': 43, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 3.4, 'coordinates': {'latitude': 40.81876, 'longitude': -73.8173}, 'transactions': ['delivery', 'pickup'], 'price': '$', 'location': {'address1': '4106 E Tremont Ave', 'address2':  ...
# Rating for 'VPho and Pizzeria': 4.9
# Review Count for 'VPho and Pizzeria': 7
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-40-57cac83d2894> in <cell line: 2>()
#      19
#      20     # Call the API for each row's latitude and longitude not in restaurants_to_remove
# ---> 21     api_response_restaurants, restaurant_list = query_api(row['latitude'], row['longitude'])
#      22     print(restaurant_list)
#      23     print(api_response_restaurants)
#
# <ipython-input-39-d3b086cceb79> in query_api(Latitude, Longitude)
#       8     data = response.json()
#       9     business_names = [business['name'] for business in data['businesses']]
# ---> 10   return data['businesses'], business_names
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %%
df_bronx_sorted
# Out:
#                                                       dba   boro building  \
# 3290       COLLEGE OF MOUNT SAINT VINCENT (Mag's Kitchen)  Bronx     6301
# 67407   COLLEGE OF MOUNT ST.VINCENT (HUDSON HEIGHTS; 1...  Bronx     6301
# 99666                      COLLEGE OF MOUNT SAINT VINCENT  Bronx     6301
# 54193                                 Marianne Pizza Cafe  Bronx     6100
# 2281                                   EJ'S BAKERY & CAFE  Bronx      462
# ...                                                   ...    ...      ...
# 72924                                            7 SPICES  Bronx   906908
# 85660                             GOLDEN EAGLE RESTAURANT  Bronx    97579
# 95074                     BAR & RESTAURANT EL SALVADORENO  Bronx   451455
# 105731                             CHOP-STICKS RESTAURANT  Bronx     7718
# 22073                                ENZO'S OF ARTHUR AVE  Bronx      NaN
#
#                     street  zipcode       phone cuisine_description  \
# 3290      RIVERDALE AVENUE  10471.0  7184053486          Coffee/Tea
# 67407     RIVERDALE AVENUE  10471.0  7184053486            American
# 99666     RIVERDALE AVENUE  10471.0  7184053486            American
# 54193     RIVERDALE AVENUE  10471.0  9144717274               Pizza
# 2281      WEST  261 STREET  10471.0  3479490023             Spanish
# ...                    ...      ...         ...                 ...
# 72924         E GUNHILL RD      NaN  3473268646           Caribbean
# 85660   MORRIS PARK AVENUE      NaN  7188634028            American
# 95074        MORRIS PK AVE      NaN  3478794891      Latin American
# 105731           21 AVENUE      NaN  7182048119             Chinese
# 22073           ARTHUR AVE  10458.0  7187334455             Italian
#
#          latitude  longitude  yelp_rating  yelp_review_count
# 3290    40.912822 -73.902504          NaN                NaN
# 67407   40.912822 -73.902504          NaN                NaN
# 99666   40.912822 -73.902504          NaN                NaN
# 54193   40.910473 -73.903108          NaN                NaN
# 2281    40.910012 -73.902671          NaN                NaN
# ...           ...        ...          ...                ...
# 72924    0.000000   0.000000          NaN                NaN
# 85660    0.000000   0.000000          NaN                NaN
# 95074    0.000000   0.000000          NaN                NaN
# 105731   0.000000   0.000000          NaN                NaN
# 22073         NaN        NaN          NaN                NaN
#
# [1725 rows x 11 columns]

# %%
df_bronx_sorted.isna().sum()
# Out:
# dba                      0
# boro                     0
# building                 1
# street                   0
# zipcode                 25
# phone                    0
# cuisine_description      0
# latitude                 1
# longitude                1
# yelp_rating            374
# yelp_review_count      374
# dtype: int64

# %%
df_bronx_final = df_bronx_sorted.dropna(subset=['yelp_rating', 'yelp_review_count'], how='any')
df_bronx_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1351 entries, 66782 to 17810
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dba                  1351 non-null   object
#  1   boro                 1351 non-null   object
#  2   building             1351 non-null   object
#  3   street               1351 non-null   object
#  4   zipcode              1351 non-null   float64
#  5   phone                1351 non-null   object
#  6   cuisine_description  1351 non-null   object
#  7   latitude             1351 non-null   float64
#  8   longitude            1351 non-null   float64
#  9   yelp_rating          1351 non-null   float64
#  10  yelp_review_count    1351 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 126.7+ KB

# %%
# 2nd token
def query_api(Latitude, Longitude):
  TOKEN = token["token2"]
  headers = { "accept": "application/json", "Authorization": f"Bearer {TOKEN}"}
  url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={Latitude}&longitude={Longitude}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
  response = requests.get(url, headers=headers)
  if response.status_code == 200:
    data = response.json()
    business_names = [business['name'] for business in data['businesses']]
  return data['businesses'], business_names

# %%
# 3rd token
def query_api(Latitude, Longitude):
  TOKEN = token["token3"]
  headers = { "accept": "application/json", "Authorization": f"Bearer {TOKEN}"}
  url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={Latitude}&longitude={Longitude}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
  response = requests.get(url, headers=headers)
  if response.status_code == 200:
    data = response.json()
    business_names = [business['name'] for business in data['businesses']]
  return data['businesses'], business_names

# %%
# 4th token
def query_api(Latitude, Longitude):
  TOKEN = token["token4"]
  headers = { "accept": "application/json", "Authorization": f"Bearer {TOKEN}"}
  url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={Latitude}&longitude={Longitude}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
  response = requests.get(url, headers=headers)
  if response.status_code == 200:
    data = response.json()
    business_names = [business['name'] for business in data['businesses']]
  return data['businesses'], business_names

# %%
# 5th token
def query_api(Latitude, Longitude):
  TOKEN = token["token5"]
  headers = { "accept": "application/json", "Authorization": f"Bearer {TOKEN}"}
  url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={Latitude}&longitude={Longitude}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
  response = requests.get(url, headers=headers)
  if response.status_code == 200:
    data = response.json()
    business_names = [business['name'] for business in data['businesses']]
  return data['businesses'], business_names

# %%
config_file_path = 'config.json'

with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = "groupproject"
blob_name = "groupdata3_Yelp.csv"

# Convert DataFrame to CSV
output = StringIO()
df_bronx_final.to_csv(output, index=False)
data = output.getvalue()
output.close()

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

# Get a blob client using the container name and blob name
blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

# Upload the CSV data
blob_client.upload_blob(data, overwrite=True)

print(f"Uploaded {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}.")
# Out:
# Uploaded groupdata3_Yelp.csv to Azure Blob Storage in container groupproject.
